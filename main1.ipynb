# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_squared_log_error, r2_score
from xgboost import XGBRegressor 
import math

# %%
train_data =pd.read_csv('train.csv')
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
test_data = pd.read_csv('test.csv')
test_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         120        0    NaN  MnPrv
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN  MnPrv
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            HLS    AllPub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0      6    2010        WD         Normal
# 1           Gar2   12500      6    2010        WD         Normal
# 2            NaN       0      3    2010        WD         Normal
# 3            NaN       0      6    2010        WD         Normal
# 4            NaN       0      1    2010        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [1459 rows x 80 columns]

# %%
train_data.isna().sum().sort_values(ascending=False).head(25)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Id                 0
# Functional         0
# Fireplaces         0
# KitchenQual        0
# KitchenAbvGr       0
# BedroomAbvGr       0
# dtype: int64

# %%
train_data = train_data.fillna(value=dict(train_data.select_dtypes(include=['int', 'float']).mean()))
test_data = test_data.fillna(value=dict(test_data.select_dtypes(include=['int', 'float']).mean()))

# %%
train_data = train_data.fillna(value='NA')
test_data = test_data.fillna(value='NA')

# %%
pd.set_option('display.max_rows',80)
train_data.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
Replacement_nums = {"LandSlope": {"Gtl": 1,"Mod": 2,"Sev": 3},                                             
                    "ExterQual": {'Po':0, 'Fa': 1, 'TA':2, 'Gd':3,  'Ex': 4},
                    "ExterCond": {'Po':0, 'Fa': 1, 'TA':2, 'Gd':3,  'Ex': 4},
                    "BsmtQual":{'NA':0 , 'Po':1, 'Fa':2, 'TA':3, 'Gd':4,  'Ex': 5},
                    "BsmtCond": {'NA':0 , 'Po':1, 'Fa':2, 'TA':3,'Gd':4, 'Ex': 5},
                    "BsmtExposure": {'NA':0, 'No':1, 'Mn':2, 'Av':3, 'Gd':4},
                    "BsmtFinType1": {'NA':0,'Unf':1,'LwQ':2, 'Rec':3,'BLQ':4,'ALQ':5, 'GLQ':6},
                    "BsmtFinType2": {'NA':0,'Unf':1,'LwQ':2, 'Rec':3,'BLQ':4,'ALQ':5, 'GLQ':6},
                    "HeatingQC": {'Po':0,'Fa':1,'TA':2,'Gd':2,'Ex':3},
                    "CentralAir": {'N':0,'Y':1},
                    "KitchenQual": {'NA':0,'Po':1,'Fa':2,'TA':3,'Gd':4,'Ex':5},
                    "FireplaceQu": {'NA':0 , 'Po':1, 'Fa':2, 'TA':3,'Gd':4, 'Ex': 5},
                    "GarageFinish": {'NA':0 , 'Unf':1, 'RFn':2, 'Fin':3},
                    "GarageQual": {'NA':0 , 'Po':1, 'Fa':2, 'TA':3,'Gd':4, 'Ex': 5},
                    "GarageCond":{'NA':0 , 'Po':1, 'Fa':2, 'TA':3,'Gd':4, 'Ex': 5},
                    "PavedDrive": {'N':0, 'P':1,'Y':2},
                    "PoolQC": {'NA':0 , 'Fa':1, 'TA':2,'Gd':3, 'Ex': 4}
                                                   }
train_data = train_data.replace(Replacement_nums)
test_data = test_data.replace(Replacement_nums)

# %%
Categorical_list1 = list(train_data.select_dtypes(include=['object']).columns)
train_data = pd.get_dummies(train_data,prefix=Categorical_list1,columns=Categorical_list1,dtype=int)
Categorical_list2 = list(test_data.select_dtypes(include=['object']).columns)
test_data = pd.get_dummies(test_data,prefix=Categorical_list2,columns=Categorical_list2,dtype=int)

# %%
train_X = train_data.loc[:,(train_data.columns != 'SalePrice') & (train_data.columns != 'Id')]
train_Y = train_data['SalePrice']
test_X = test_data.loc[:,test_data.columns != 'Id']

# %%
In_Train_Not_Test = []
for i in train_X.columns:
    if i not in test_X.columns:
        test_X.insert(test_X.shape[1],i,0)
        In_Train_Not_Test.append(i)

In_Test_Not_Train = []     
for i in test_X.columns:
    if i not in train_X.columns:
        In_Test_Not_Train.append(i)

# Dropping the features in test data which are not present in train data
test_X = test_X.drop(columns=In_Test_Not_Train)
# Making the column order same in feature vectors
test_X = test_X[train_X.columns]

# %%
print(f"Shape of train_X: {train_X.shape} and test_X: {test_X.shape}")
# Out:
# Shape of train_X: (1460, 240) and test_X: (1459, 240)

# %%
train_X, CV_X, train_Y, CV_Y = train_test_split(train_X,train_Y,test_size=0.20,random_state=1)

# #To train model on complete data
# CV_X = train_X
# CV_Y = train_Y

# %%
from sklearn.model_selection import GridSearchCV

# %%
xgb_model = XGBRegressor()

param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
}

grid_search = GridSearchCV(
    xgb_model,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=5,
    verbose=1,
    n_jobs=-1,
)

grid_search.fit(train_X, train_Y)

# Display the best parameters and corresponding score
print("Best Parameters:", grid_search.best_params_)
print("Best Negative Mean Squared Error:", grid_search.best_score_)

# Evaluate the best model on the test set
best_model = grid_search.best_estimator_
y_pred = best_model.predict(CV_X)
rmse = np.sqrt(mean_squared_error(CV_Y, y_pred))
print("Root Mean Squared Error on Test Set:", rmse)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# g:\My Drive\Projects\House Prices - Advanced Regression Techniques\main1.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> param_grid = {
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>     'n_estimators': [50, 100, 200],
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a>     'learning_rate': [0.01, 0.1, 0.2],
#    (...)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a>     'colsample_bytree': [0.8, 0.9, 1.0],
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> }
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a> grid_search = GridSearchCV(
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a>     xgb_model,
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a>     param_grid=param_grid,
#    (...)
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=16'>17</a>     n_jobs=-1,
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=17'>18</a> )
# ---> <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=19'>20</a> grid_search.fit(train_X, train_Y)
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=21'>22</a> # Display the best parameters and corresponding score
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projects/House%20Prices%20-%20Advanced%20Regression%20Techniques/main1.ipynb#X20sZmlsZQ%3D%3D?line=22'>23</a> print("Best Parameters:", grid_search.best_params_)
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
best_parameters = grid_search.best_params_
best_parameters
# Out:
# {'colsample_bytree': 0.9,
#  'learning_rate': 0.2,
#  'max_depth': 3,
#  'n_estimators': 200,
#  'subsample': 1.0}

# %%
xgb_model = XGBRegressor(n_estimators=200, 
                         max_depth=3, 
                         learning_rate=0.2, 
                         eval_metric=mean_squared_log_error, 
                         colsample_bytree = 0.9,
                         subsample = 1.0,
                         reg_lamba=10,
                         verbose=1,
                         random_state=10,
                         early_stopping_rounds=10
                         )
xgb_model.fit(train_X, train_Y, eval_set=[(CV_X, CV_Y)])
# Out:
# [0]	validation_0-rmse:75455.24734	validation_0-mean_squared_log_error:0.14929
# [1]	validation_0-rmse:66869.21902	validation_0-mean_squared_log_error:0.11726
# [2]	validation_0-rmse:60289.74136	validation_0-mean_squared_log_error:0.09559
# [3]	validation_0-rmse:54776.59032	validation_0-mean_squared_log_error:0.08048
# [4]	validation_0-rmse:50459.26162	validation_0-mean_squared_log_error:0.06772
# [5]	validation_0-rmse:46461.33284	validation_0-mean_squared_log_error:0.05736
# [6]	validation_0-rmse:43770.84379	validation_0-mean_squared_log_error:0.05095
# [7]	validation_0-rmse:40022.11600	validation_0-mean_squared_log_error:0.04470
# [8]	validation_0-rmse:38401.63008	validation_0-mean_squared_log_error:0.03961
# [9]	validation_0-rmse:36750.19749	validation_0-mean_squared_log_error:0.03643
# [10]	validation_0-rmse:34681.90390	validation_0-mean_squared_log_error:0.03268
# [11]	validation_0-rmse:32685.19328	validation_0-mean_squared_log_error:0.02957
# [12]	validation_0-rmse:31913.66825	validation_0-mean_squared_log_error:0.02783
# [13]	validation_0-rmse:31313.73401	validation_0-mean_squared_log_error:0.02657
# [14]	validation_0-rmse:29948.84605	validation_0-mean_squared_log_error:0.02508
# [15]	validation_0-rmse:29105.44179	validation_0-mean_squared_log_error:0.02387
# [16]	validation_0-rmse:28602.66120	validation_0-mean_squared_log_error:0.02287
# [17]	validation_0-rmse:27825.02088	validation_0-mean_squared_log_error:0.02183
# [18]	validation_0-rmse:27397.27371	validation_0-mean_squared_log_error:0.02120
# [19]	validation_0-rmse:27105.94618	validation_0-mean_squared_log_error:0.02067
# [20]	validation_0-rmse:26523.72385	validation_0-mean_squared_log_error:0.02009
# [21]	validation_0-rmse:26317.38433	validation_0-mean_squared_log_error:0.01986
# [22]	validation_0-rmse:25777.95348	validation_0-mean_squared_log_error:0.01963
# [23]	validation_0-rmse:25680.00561	validation_0-mean_squared_log_error:0.01933
# [24]	validation_0-rmse:25195.14458	validation_0-mean_squared_log_error:0.01882
# [25]	validation_0-rmse:24867.82808	validation_0-mean_squared_log_error:0.01877
# [26]	validation_0-rmse:24689.07729	validation_0-mean_squared_log_error:0.01869
# [27]	validation_0-rmse:24502.96433	validation_0-mean_squared_log_error:0.01835
# [28]	validation_0-rmse:24454.83729	validation_0-mean_squared_log_error:0.01805
# [29]	validation_0-rmse:24199.96677	validation_0-mean_squared_log_error:0.01784
# [30]	validation_0-rmse:24119.94353	validation_0-mean_squared_log_error:0.01758
# [31]	validation_0-rmse:24148.58109	validation_0-mean_squared_log_error:0.01744
# [32]	validation_0-rmse:24163.35568	validation_0-mean_squared_log_error:0.01742
# [33]	validation_0-rmse:24221.76890	validation_0-mean_squared_log_error:0.01742
# [34]	validation_0-rmse:24129.03786	validation_0-mean_squared_log_error:0.01702
# [35]	validation_0-rmse:24093.94581	validation_0-mean_squared_log_error:0.01692
# [36]	validation_0-rmse:24203.67771	validation_0-mean_squared_log_error:0.01690
# [37]	validation_0-rmse:24135.71454	validation_0-mean_squared_log_error:0.01669
# [38]	validation_0-rmse:24043.07400	validation_0-mean_squared_log_error:0.01663
# [39]	validation_0-rmse:24189.50114	validation_0-mean_squared_log_error:0.01658
# [40]	validation_0-rmse:24204.95355	validation_0-mean_squared_log_error:0.01658
# [41]	validation_0-rmse:24131.59128	validation_0-mean_squared_log_error:0.01656
# [42]	validation_0-rmse:24070.18556	validation_0-mean_squared_log_error:0.01645
# [43]	validation_0-rmse:24153.68252	validation_0-mean_squared_log_error:0.01646
# c:\Users\steph\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:160: UserWarning: [22:52:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0750514818a16474a-1\xgboost\xgboost-ci-windows\src\learner.cc:742:
# Parameters: { "reg_lamba", "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [44]	validation_0-rmse:24122.59429	validation_0-mean_squared_log_error:0.01641
# [45]	validation_0-rmse:23935.19104	validation_0-mean_squared_log_error:0.01614
# [46]	validation_0-rmse:23952.49184	validation_0-mean_squared_log_error:0.01626
# [47]	validation_0-rmse:23863.32829	validation_0-mean_squared_log_error:0.01601
# [48]	validation_0-rmse:23850.77053	validation_0-mean_squared_log_error:0.01599
# [49]	validation_0-rmse:23893.80408	validation_0-mean_squared_log_error:0.01597
# [50]	validation_0-rmse:23748.29285	validation_0-mean_squared_log_error:0.01600
# [51]	validation_0-rmse:23760.08061	validation_0-mean_squared_log_error:0.01595
# [52]	validation_0-rmse:23755.77538	validation_0-mean_squared_log_error:0.01589
# [53]	validation_0-rmse:23655.10625	validation_0-mean_squared_log_error:0.01589
# [54]	validation_0-rmse:23546.49472	validation_0-mean_squared_log_error:0.01576
# [55]	validation_0-rmse:23562.32262	validation_0-mean_squared_log_error:0.01574
# [56]	validation_0-rmse:23526.29719	validation_0-mean_squared_log_error:0.01568
# [57]	validation_0-rmse:23499.76064	validation_0-mean_squared_log_error:0.01569
# [58]	validation_0-rmse:23562.96590	validation_0-mean_squared_log_error:0.01577
# [59]	validation_0-rmse:23546.19614	validation_0-mean_squared_log_error:0.01581
# [60]	validation_0-rmse:23474.82659	validation_0-mean_squared_log_error:0.01574
# [61]	validation_0-rmse:23468.39641	validation_0-mean_squared_log_error:0.01555
# [62]	validation_0-rmse:23493.91292	validation_0-mean_squared_log_error:0.01568
# [63]	validation_0-rmse:23474.09663	validation_0-mean_squared_log_error:0.01567
# [64]	validation_0-rmse:23469.77224	validation_0-mean_squared_log_error:0.01566
# [65]	validation_0-rmse:23428.63375	validation_0-mean_squared_log_error:0.01556
# [66]	validation_0-rmse:23366.56695	validation_0-mean_squared_log_error:0.01548
# [67]	validation_0-rmse:23317.03894	validation_0-mean_squared_log_error:0.01551
# [68]	validation_0-rmse:23405.36995	validation_0-mean_squared_log_error:0.01554
# [69]	validation_0-rmse:23421.15209	validation_0-mean_squared_log_error:0.01549
# [70]	validation_0-rmse:23384.86957	validation_0-mean_squared_log_error:0.01550
# [71]	validation_0-rmse:23418.36197	validation_0-mean_squared_log_error:0.01562
# [72]	validation_0-rmse:23424.94744	validation_0-mean_squared_log_error:0.01563
# [73]	validation_0-rmse:23423.48085	validation_0-mean_squared_log_error:0.01563
# [74]	validation_0-rmse:23437.53738	validation_0-mean_squared_log_error:0.01568
# [75]	validation_0-rmse:23434.91693	validation_0-mean_squared_log_error:0.01570
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9, device=None, early_stopping_rounds=10,
#              enable_categorical=False,
#              eval_metric=<function mean_squared_log_error at 0x00000145B923B1A0>,
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, random_state=10, ...)

# %%
yhat_train_XGB = xgb_model.predict(train_X)
yhat_CV_XGB = xgb_model.predict(CV_X)
RMSE_log2_train = math.sqrt(((np.log2(train_Y) - np.log2(yhat_train_XGB))**2).sum()/len(train_Y))
print(f"The RMSE of log2 of values on training data is: {RMSE_log2_train}")
RMSE_log2_CV = math.sqrt(((np.log2(CV_Y) - np.log2(yhat_CV_XGB))**2).sum()/len(CV_Y))
print(f"The RMSE of log2 of values on CV data is: {RMSE_log2_CV}")
# Out:
# The RMSE of log2 of values on training data is: 0.07346137587410438
# The RMSE of log2 of values on CV data is: 0.1841501973326533

# %%
yhat_train_XGB
# Out:
# array([147911.3  , 109513.7  , 184678.42 , ..., 125634.15 ,  95824.055,
#         81773.15 ], dtype=float32)

# %%
my_predictions = xgb_model.predict(test_X)
df_output = pd.DataFrame()
df_output['Id'] = test_data['Id']
df_output['SalePrice'] = my_predictions
df_output[['Id', 'SalePrice']].to_csv('mypredictions1.csv', index=False)
